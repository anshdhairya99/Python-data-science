# %% [markdown]
# # Pandas Library in Python :---

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
# change and apply theme
print(plt.style.available)
plt.style.use('ggplot')
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %% [markdown]
# - load & select the data (1%-10%)
# - process the data (60% - 80%)
# - visualize the data(~%)

# %%
pd.set_option('display.max_columns', None)

# %%
Canada = pd.read_excel('Canada.xlsx', sheet_name=1, skiprows=20, skipfooter=2)

# %%
pd.read_excel('Canada.xlsx')
# Out:
#                                            Unnamed: 0  Unnamed: 1  \
# 0                                                 NaN         NaN
# 1                                                 NaN         NaN
# 2                                                 NaN         NaN
# 3                                      United Nations         NaN
# 4                                 Population Division         NaN
# 5           Department of Economic and Social Affairs         NaN
# 6                                                 NaN         NaN
# 7   International Migration Flows to and from Sele...         NaN
# 8                                                 NaN         NaN
# 9                            POP/DB/MIG/Flow/Rev.2015         NaN
# 10  December 2015 - Copyright © 2015 by United Nat...         NaN
# 11  Suggested citation: United Nations, Department...         NaN
# 12   International Migration Flows to and from Sel...         NaN
# ...

# %%
pd.read_excel('Canada.xlsx',sheet_name=1)
# Out:
#               Unnamed: 0  Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0                    NaN         NaN        NaN        NaN        NaN
# 1                    NaN         NaN        NaN        NaN        NaN
# 2                    NaN         NaN        NaN        NaN        NaN
# 3         United Nations         NaN        NaN        NaN        NaN
# 4    Population Division         NaN        NaN        NaN        NaN
# ..                   ...         ...        ...        ...        ...
# 212           Immigrants  Foreigners      Yemen        935       Asia
# 213           Immigrants  Foreigners     Zambia        903     Africa
# 214           Immigrants  Foreigners   Zimbabwe        903     Africa
# 215           Immigrants  Foreigners    Unknown        999      World
# 216           Immigrants        Both      Total        999      World
#
#     Unnamed: 5      Unnamed: 6 Unnamed: 7          Unnamed: 8  Unnamed: 9  \
# ...

# %%
# skip the banner
pd.read_excel('Canada.xlsx',sheet_name=1, skiprows=20)

# %%
pd.read_excel('Canada.xlsx',sheet_name=1,skiprows=20,skipfooter=2)
# Out:
#            Type    Coverage          OdName  AREA AreaName   REG  \
# 0    Immigrants  Foreigners     Afghanistan   935     Asia  5501
# 1    Immigrants  Foreigners         Albania   908   Europe   925
# 2    Immigrants  Foreigners         Algeria   903   Africa   912
# 3    Immigrants  Foreigners  American Samoa   909  Oceania   957
# 4    Immigrants  Foreigners         Andorra   908   Europe   925
# ..          ...         ...             ...   ...      ...   ...
# 190  Immigrants  Foreigners        Viet Nam   935     Asia   920
# 191  Immigrants  Foreigners  Western Sahara   903   Africa   912
# 192  Immigrants  Foreigners           Yemen   935     Asia   922
# 193  Immigrants  Foreigners          Zambia   903   Africa   910
# 194  Immigrants  Foreigners        Zimbabwe   903   Africa   910
#
#                 RegName  DEV             DevName  1980  1981  1982  1983  \
# 0         Southern Asia  902  Developing regions    16    39    39    47
# ...

# %%
pd.set_option('display.max_columns', None)

# %%
Canada = pd.read_excel('Canada.xlsx',sheet_name=1,skiprows=20,skipfooter=2)

# %% [markdown]
# - Data Frame -> 2D matrix with rows and cols
# - Series -> 1D matrix with 1 cols

# %% [markdown]
# ### selection of data
# - head - top 5
# - tail - last 5
# - sample - random record

# %%
Canada.head(3)
# Out:
#          Type    Coverage       OdName  AREA AreaName   REG          RegName  \
# 0  Immigrants  Foreigners  Afghanistan   935     Asia  5501    Southern Asia
# 1  Immigrants  Foreigners      Albania   908   Europe   925  Southern Europe
# 2  Immigrants  Foreigners      Algeria   903   Africa   912  Northern Africa
#
#    DEV             DevName  1980  1981  1982  1983  1984  1985  1986  1987  \
# 0  902  Developing regions    16    39    39    47    71   340   496   741
# 1  901   Developed regions     1     0     0     0     0     0     1     2
# 2  902  Developing regions    80    67    71    69    63    44    69   132
#
#    1988  1989  1990  1991  1992  1993  1994  1995  1996  1997  1998  1999  \
# 0   828  1076  1028  1378  1170   713   858  1537  2212  2555  1999  2395
# 1     2     3     3    21    56    96    71    63   113   307   574  1264
# 2   242   434   491   872   795   717   595  1106  2054  1842  2292  2389
#
# ...

# %%
Canada.head(2)
# Out:
#          Type    Coverage       OdName  AREA AreaName   REG          RegName  \
# 0  Immigrants  Foreigners  Afghanistan   935     Asia  5501    Southern Asia
# 1  Immigrants  Foreigners      Albania   908   Europe   925  Southern Europe
#
#    DEV             DevName  1980  1981  1982  1983  1984  1985  1986  1987  \
# 0  902  Developing regions    16    39    39    47    71   340   496   741
# 1  901   Developed regions     1     0     0     0     0     0     1     2
#
#    1988  1989  1990  1991  1992  1993  1994  1995  1996  1997  1998  1999  \
# 0   828  1076  1028  1378  1170   713   858  1537  2212  2555  1999  2395
# 1     2     3     3    21    56    96    71    63   113   307   574  1264
#
#    2000  2001  2002  2003  2004  2005  2006  2007  2008  2009  2010  2011  \
# 0  3326  4067  3697  3479  2978  3436  3009  2652  2111  1746  1758  2203
# 1  1816  1602  1021   853  1450  1223   856   702   560   716   561   539
#
#    2012  2013
# 0  2635  2004
# 1   620   603

# %%
Canada.tail(5)
# Out:
#            Type    Coverage          OdName  AREA AreaName  REG  \
# 190  Immigrants  Foreigners        Viet Nam   935     Asia  920
# 191  Immigrants  Foreigners  Western Sahara   903   Africa  912
# 192  Immigrants  Foreigners           Yemen   935     Asia  922
# 193  Immigrants  Foreigners          Zambia   903   Africa  910
# 194  Immigrants  Foreigners        Zimbabwe   903   Africa  910
#
#                 RegName  DEV             DevName  1980  1981  1982  1983  \
# 190  South-Eastern Asia  902  Developing regions  1191  1829  2162  3404
# 191     Northern Africa  902  Developing regions     0     0     0     0
# 192        Western Asia  902  Developing regions     1     2     1     6
# 193      Eastern Africa  902  Developing regions    11    17    11     7
# 194      Eastern Africa  902  Developing regions    72   114   102    44
#
#      1984  1985  1986  1987  1988  1989  1990  1991  1992  1993  1994  1995  \
# ...

# %%
Canada.sample()
# Out:
#            Type    Coverage   OdName  AREA AreaName  REG          RegName  \
# 176  Immigrants  Foreigners  Tunisia   903   Africa  912  Northern Africa
#
#      DEV             DevName  1980  1981  1982  1983  1984  1985  1986  1987  \
# 176  902  Developing regions    58    51    55    46    51    57    64    86
#
#      1988  1989  1990  1991  1992  1993  1994  1995  1996  1997  1998  1999  \
# 176   130   242   326   306   315   245   197   271   256   242   237   323
#
#      2000  2001  2002  2003  2004  2005  2006  2007  2008  2009  2010  2011  \
# 176   437   788   661   669   764   756  1065   869   950  1195  1299  1442
#
#      2012  2013
# 176  1503  1627

# %% [markdown]
# - single column
#    - dict style
#    - object
# - multiple columns
#    - list style

# %%
Canada['OdName']
# Out:
# 0         Afghanistan
# 1             Albania
# 2             Algeria
# 3      American Samoa
# 4             Andorra
#             ...
# 190          Viet Nam
# 191    Western Sahara
# 192             Yemen
# 193            Zambia
# 194          Zimbabwe
# Name: OdName, Length: 195, dtype: object

# %%
Canada.OdName
# Out:
# 0         Afghanistan
# 1             Albania
# 2             Algeria
# 3      American Samoa
# 4             Andorra
#             ...
# 190          Viet Nam
# 191    Western Sahara
# 192             Yemen
# 193            Zambia
# 194          Zimbabwe
# Name: OdName, Length: 195, dtype: object

# %%
Canada['AreaName']
# Out:
# 0         Asia
# 1       Europe
# 2       Africa
# 3      Oceania
# 4       Europe
#         ...
# 190       Asia
# 191     Africa
# 192       Asia
# 193     Africa
# 194     Africa
# Name: AreaName, Length: 195, dtype: object

# %%
Canada[2010]
# Out:
# 0      1758
# 1       561
# 2      4752
# 3         0
# 4         0
#        ...
# 190    1942
# 191       0
# 192     211
# 193     102
# 194     494
# Name: 2010, Length: 195, dtype: int64

# %%
Canada['OdName']
# Out:
# 0         Afghanistan
# 1             Albania
# 2             Algeria
# 3      American Samoa
# 4             Andorra
#             ...
# 190          Viet Nam
# 191    Western Sahara
# 192             Yemen
# 193            Zambia
# 194          Zimbabwe
# Name: OdName, Length: 195, dtype: object

# %%
Canada.OdName
# Out:
# 0         Afghanistan
# 1             Albania
# 2             Algeria
# 3      American Samoa
# 4             Andorra
#             ...
# 190          Viet Nam
# 191    Western Sahara
# 192             Yemen
# 193            Zambia
# 194          Zimbabwe
# Name: OdName, Length: 195, dtype: object

# %%
cols = ['OdName', 1980, 1990, 2000, 2010]
Canada[cols] # list of columns -> return dataframe
# Out:
#              OdName  1980  1990  2000  2010
# 0       Afghanistan    16  1028  3326  1758
# 1           Albania     1     3  1816   561
# 2           Algeria    80   491  2867  4752
# 3    American Samoa     0     2     0     0
# 4           Andorra     0     3     0     0
# ..              ...   ...   ...   ...   ...
# 190        Viet Nam  1191  3801  1803  1942
# 191  Western Sahara     0     0     0     0
# 192           Yemen     1     4   122   211
# 193          Zambia    11    77    39   102
# 194        Zimbabwe    72   129    98   494
#
# [195 rows x 5 columns]

# %% [markdown]
# Row wise data access slicing
# - iloc[] - index location
# - loc[] - labelled location
#
# - this is attribute

# %%
Canada.iloc[66]
# Out:
# Type                Immigrants
# Coverage            Foreigners
# OdName                 Georgia
# AREA                       935
# AreaName                  Asia
# REG                        922
# RegName           Western Asia
# DEV                        902
# DevName     Developing regions
# 1980                         0
# 1981                         0
# 1982                         0
# 1983                         0
# 1984                         0
# 1985                         0
# 1986                         0
# 1987                         0
# 1988                         0
# 1989                         0
# 1990                         0
# 1991                         0
# 1992                         8
# 1993                        22
# 1994                        27
# 1995                        67
# 1996                        49
# 1997                        46
# 1998                        92
# 1999                        46
# 2000                        83
# ...

# %%
Canada.index
# Out:
# RangeIndex(start=0, stop=195, step=1)

# %%
Canada.set_index('OdName', inplace=True) # set the 'OdName' column as the index

# %%
Canada.index
# Out:
# Index(['Afghanistan', 'Albania', 'Algeria', 'American Samoa', 'Andorra',
#        'Angola', 'Antigua and Barbuda', 'Argentina', 'Armenia', 'Australia',
#        ...
#        'United States of America', 'Uruguay', 'Uzbekistan', 'Vanuatu',
#        'Venezuela (Bolivarian Republic of)', 'Viet Nam', 'Western Sahara',
#        'Yemen', 'Zambia', 'Zimbabwe'],
#       dtype='object', name='OdName', length=195)

# %%
Canada.loc['Cambodia']
# Out:
# Type                Immigrants
# Coverage            Foreigners
# AREA                       935
# AreaName                  Asia
# REG                        920
# RegName     South-Eastern Asia
# DEV                        902
# DevName     Developing regions
# 1980                        12
# 1981                        19
# 1982                        26
# 1983                        33
# 1984                        10
# 1985                         7
# 1986                         8
# 1987                        14
# 1988                        15
# 1989                        27
# 1990                        34
# 1991                        38
# 1992                        93
# 1993                       418
# 1994                       371
# 1995                       286
# 1996                       216
# 1997                       313
# 1998                       241
# 1999                       165
# 2000                       245
# 2001                       259
# ...

# %%
years = list(range(1980, 2014))
print(years)
# Out:
# [1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013]

# %%
Canada.loc['Japan', years].plot(kind='area', title='Japan Immigration to Canada', figsize=(15,5))
# Out:
# <Axes: title={'center': 'Japan Immigration to Canada'}>

# %%
countries = ['Cambodia', 'Japan', 'France']
Canada.loc[countries, years]
# Out:
#           1980  1981  1982  1983  1984  1985  1986  1987  1988  1989  1990  \
# OdName
# Cambodia    12    19    26    33    10     7     8    14    15    27    34
# Japan      701   756   598   309   246   198   248   422   324   494   379
# France    1729  2027  2219  1490  1169  1177  1298  1658  2038  2332  2177
#
#           1991  1992  1993  1994  1995  1996  1997  1998  1999  2000  2001  \
# OdName
# Cambodia    38    93   418   371   286   216   313   241   165   245   259
# Japan      506   605   907   956   826   994   924   897  1083  1010  1092
# France    2911  3487  3709  2759  3332  2623  2473  3214  3343  3765  3806
#
#           2002  2003  2004  2005  2006  2007  2008  2009  2010  2011  2012  \
# OdName
# Cambodia   230   277   348   370   529   460   354   203   200   196   233
# Japan      806   817   973  1067  1212  1250  1284  1194  1168  1265  1214
# France    3463  3568  4391  4429  4002  4290  4532  5051  4646  4080  6280
#
#           2013
# OdName
# ...

# %%
Canada.loc[countries, years].T.plot(kind='line', title=f'{", ".join(countries)}', figsize=(15,5))
plt.savefig('comparing-3-countries.png')

# %% [markdown]
# - sort_index helps to sort the index of the dataframe if it is not sorted

# %%
Canada.sort_index(ascending=False)
# Out:
#                       Type    Coverage  AREA AreaName   REG  \
# OdName
# Zimbabwe        Immigrants  Foreigners   903   Africa   910
# Zambia          Immigrants  Foreigners   903   Africa   910
# Yemen           Immigrants  Foreigners   935     Asia   922
# Western Sahara  Immigrants  Foreigners   903   Africa   912
# Viet Nam        Immigrants  Foreigners   935     Asia   920
# ...                    ...         ...   ...      ...   ...
# Andorra         Immigrants  Foreigners   908   Europe   925
# American Samoa  Immigrants  Foreigners   909  Oceania   957
# Algeria         Immigrants  Foreigners   903   Africa   912
# Albania         Immigrants  Foreigners   908   Europe   925
# Afghanistan     Immigrants  Foreigners   935     Asia  5501
#
#                            RegName  DEV             DevName  1980  1981  1982  \
# OdName
# Zimbabwe            Eastern Africa  902  Developing regions    72   114   102
# ...

# %% [markdown]
# sort_value() help us to sort the values in ascending or descending order of given column.

# %%
Canada.sort_values(by='AreaName', inplace=True)

# %%
Canada.sort_values(by=['AreaName','DevName'], ascending=[True,False])
# Out:
#                         Type    Coverage  AREA AreaName  REG  \
# OdName
# Lesotho           Immigrants  Foreigners   903   Africa  913
# Mali              Immigrants  Foreigners   903   Africa  914
# Malawi            Immigrants  Foreigners   903   Africa  910
# Madagascar        Immigrants  Foreigners   903   Africa  910
# Libya             Immigrants  Foreigners   903   Africa  912
# ...                      ...         ...   ...      ...  ...
# Samoa             Immigrants  Foreigners   909  Oceania  957
# Fiji              Immigrants  Foreigners   909  Oceania  928
# Marshall Islands  Immigrants  Foreigners   909  Oceania  954
# Australia         Immigrants  Foreigners   909  Oceania  927
# New Zealand       Immigrants  Foreigners   909  Oceania  927
#
#                                     RegName  DEV             DevName  1980  \
# OdName
# Lesotho                     Southern Africa  902  Developing regions     1
# ...

# %% [markdown]
# - - Filter :-

# %%
Canada['AreaName'] == "Africa" # filter
# Out:
# OdName
# Lesotho              True
# Mali                 True
# Malawi               True
# Madagascar           True
# Libya                True
#                     ...
# Tonga               False
# Samoa               False
# Fiji                False
# New Zealand         False
# Marshall Islands    False
# Name: AreaName, Length: 195, dtype: bool

# %%
Canada[Canada['AreaName'] == "Oceania"]
# Out:
#                         Type    Coverage  AREA AreaName  REG  \
# OdName
# Kiribati          Immigrants  Foreigners   909  Oceania  954
# Palau             Immigrants  Foreigners   909  Oceania  954
# Vanuatu           Immigrants  Foreigners   909  Oceania  928
# Papua New Guinea  Immigrants  Foreigners   909  Oceania  928
# Australia         Immigrants  Foreigners   909  Oceania  927
# New Caledonia     Immigrants  Foreigners   909  Oceania  928
# American Samoa    Immigrants  Foreigners   909  Oceania  957
# Tuvalu            Immigrants  Foreigners   909  Oceania  957
# Nauru             Immigrants  Foreigners   909  Oceania  954
# Tonga             Immigrants  Foreigners   909  Oceania  957
# Samoa             Immigrants  Foreigners   909  Oceania  957
# Fiji              Immigrants  Foreigners   909  Oceania  928
# New Zealand       Immigrants  Foreigners   909  Oceania  927
# Marshall Islands  Immigrants  Foreigners   909  Oceania  954
#
# ...

# %%
# display only those records where in the column '2013' the value is greater than 20000
Canada[Canada[2013]>20000]
# Out:
#                    Type    Coverage  AREA AreaName   REG             RegName  \
# OdName
# Philippines  Immigrants  Foreigners   935     Asia   920  South-Eastern Asia
# China        Immigrants  Foreigners   935     Asia   906        Eastern Asia
# India        Immigrants  Foreigners   935     Asia  5501       Southern Asia
#
#              DEV             DevName  1980  1981  1982  1983  1984  1985  \
# OdName
# Philippines  902  Developing regions  6051  5921  5249  4562  3801  3150
# China        902  Developing regions  5123  6682  3308  1863  1527  1816
# India        902  Developing regions  8880  8670  8147  7338  5704  4211
#
#              1986   1987   1988   1989   1990   1991   1992   1993   1994  \
# OdName
# Philippines  4166   7360   8639  11865  12509  12718  13670  20479  19532
# China        1960   2643   2758   4323   8076  14255  10846   9817  13128
# India        7150  10189  11522  10343  12041  13734  13673  21496  18620
#
# ...

# %% [markdown]
# - Stats and Maths

# %%
Canada.describe() # for numerical columns
# Out:
#              AREA          REG         DEV          1980          1981  \
# count  195.000000   195.000000  195.000000    195.000000    195.000000
# mean   912.764103  1249.015385  901.753846    508.394872    566.989744
# std     13.082835  1185.526885    0.431878   1949.588546   2152.643752
# min    903.000000   905.000000  901.000000      0.000000      0.000000
# 25%    903.000000   914.000000  902.000000      0.000000      0.000000
# 50%    908.000000   922.000000  902.000000     13.000000     10.000000
# 75%    922.000000   925.500000  902.000000    251.500000    295.500000
# max    935.000000  5501.000000  902.000000  22045.000000  24796.000000
#
#                1982          1983          1984         1985         1986  \
# count    195.000000    195.000000    195.000000   195.000000   195.000000
# mean     534.723077    387.435897    376.497436   358.861538   441.271795
# std     1866.997511   1204.333597   1198.246371  1079.309600  1225.576630
# ...

# %%
Canada.describe(exclude=np.number) # every column except for the numeric ones
# Out:
#               Type    Coverage AreaName       RegName             DevName
# count          195         195      195           195                 195
# unique           1           2        6            22                   2
# top     Immigrants  Foreigners   Africa  Western Asia  Developing regions
# freq           195         194       54            18                 147

# %%
Canada[[1980, 1990,2000,2010]].agg(['mean','median'])
# Out:
#               1980        1990        2000         2010
# mean    508.394872  964.379487  1111.34359  1420.287179
# median   13.000000   38.000000   138.00000   211.000000

# %%
Canada['AreaName'].value_counts()
# Out:
# AreaName
# Africa                             54
# Asia                               49
# Europe                             43
# Latin America and the Caribbean    33
# Oceania                            14
# Northern America                    2
# Name: count, dtype: int64

# %%
Canada['DevName'].value_counts()
# Out:
# DevName
# Developing regions    147
# Developed regions      48
# Name: count, dtype: int64

# %% [markdown]
# - Add Column

# %%
Canada[years].sum(axis=1) # Total immigration for each country
# Out:
# OdName
# Lesotho               107
# Mali                 2188
# Malawi                294
# Madagascar           2194
# Libya                4909
#                     ...
# Tonga                 142
# Samoa                  78
# Fiji                20609
# New Zealand         10386
# Marshall Islands        2
# Length: 195, dtype: int64

# %%
Canada['Total'] = Canada[years].sum(axis=1) # a new column total will be added to end of dataframe

# %%
Canada.head(2)
# Out:
#                Type    Coverage  AREA AreaName  REG          RegName  DEV  \
# OdName
# Lesotho  Immigrants  Foreigners   903   Africa  913  Southern Africa  902
# Mali     Immigrants  Foreigners   903   Africa  914   Western Africa  902
#
#                     DevName  1980  1981  1982  1983  1984  1985  1986  1987  \
# OdName
# Lesotho  Developing regions     1     1     1     2     7     5     3     1
# Mali     Developing regions     4     4     7     3     3     4     3     5
#
#          1988  1989  1990  1991  1992  1993  1994  1995  1996  1997  1998  \
# OdName
# Lesotho     6     5     1     4     4     7     2     3     9     2     1
# Mali        4     7    13    31    90    51    35    36    67    26    43
#
#          1999  2000  2001  2002  2003  2004  2005  2006  2007  2008  2009  \
# OdName
# Lesotho     4     1     0     2     2     2     4     0     4     1     8
# Mali       30    66    67    62    72    87    87   114   143   154   164
#
# ...

# %% [markdown]
# - Remove Column

# %%
cols_to_drop = ['Type','Coverage','AREA','REG','DEV']
Canada.drop(columns=cols_to_drop,inplace=True)
Canada
# Out:
#                  AreaName                    RegName             DevName  \
# OdName
# Lesotho            Africa            Southern Africa  Developing regions
# Mali               Africa             Western Africa  Developing regions
# Malawi             Africa             Eastern Africa  Developing regions
# Madagascar         Africa             Eastern Africa  Developing regions
# Libya              Africa            Northern Africa  Developing regions
# ...                   ...                        ...                 ...
# Tonga             Oceania                  Polynesia  Developing regions
# Samoa             Oceania                  Polynesia  Developing regions
# Fiji              Oceania                  Melanesia  Developing regions
# New Zealand       Oceania  Australia and New Zealand   Developed regions
# Marshall Islands  Oceania                 Micronesia  Developing regions
#
#                   1980  1981  1982  1983  1984  1985  1986  1987  1988  1989  \
# ...

# %%
Canada.drop_duplicates(subset=['AreaName']) # just an example
# Out:
#                                                  AreaName           RegName  \
# OdName
# Lesotho                                            Africa   Southern Africa
# Pakistan                                             Asia     Southern Asia
# Poland                                             Europe    Eastern Europe
# Colombia                  Latin America and the Caribbean     South America
# United States of America                 Northern America  Northern America
# Kiribati                                          Oceania        Micronesia
#
#                                      DevName  1980   1981  1982  1983  1984  \
# OdName
# Lesotho                   Developing regions     1      1     1     2     7
# Pakistan                  Developing regions   978    972  1201   900   668
# Poland                     Developed regions   863   2930  5881  4546  3588
# Colombia                  Developing regions   266    326   360   244   235
# ...

# %%
Canada.iloc[5]
# Out:
# AreaName                Africa
# RegName         Western Africa
# DevName     Developing regions
# 1980                         1
# 1981                         2
# 1982                         2
# 1983                         1
# 1984                         4
# 1985                         4
# 1986                         3
# 1987                         4
# 1988                         3
# 1989                         7
# 1990                         5
# 1991                        11
# 1992                        52
# 1993                        37
# 1994                        40
# 1995                        55
# 1996                        59
# 1997                        61
# 1998                        28
# 1999                        36
# 2000                        56
# 2001                        60
# 2002                        57
# 2003                       139
# 2004                       409
# 2005                       581
# 2006                       356
# ...

# %%
Canada.iloc[66]
# Out:
# AreaName                  Asia
# RegName     South-Eastern Asia
# DevName     Developing regions
# 1980                      6051
# 1981                      5921
# 1982                      5249
# 1983                      4562
# 1984                      3801
# 1985                      3150
# 1986                      4166
# 1987                      7360
# 1988                      8639
# 1989                     11865
# 1990                     12509
# 1991                     12718
# 1992                     13670
# 1993                     20479
# 1994                     19532
# 1995                     15864
# 1996                     13692
# 1997                     11549
# 1998                      8735
# 1999                      9734
# 2000                     10763
# 2001                     13836
# 2002                     11707
# 2003                     12758
# 2004                     14004
# 2005                     18139
# 2006                     18400
# ...

# %%
Canada.iloc[66, 39]
# row and colm
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 Canada.iloc[66, 39]
#
# File c:\Users\Dell\miniconda3\lib\site-packages\pandas\core\indexing.py:1096, in _LocationIndexer.__getitem__(self, key)
#    1094     key = tuple(com.apply_if_callable(x, self.obj) for x in key)
#    1095     if self._is_scalar_access(key):
# -> 1096         return self.obj._get_value(*key, takeable=self._takeable)
#    1097     return self._getitem_tuple(key)
#    1098 else:
#    1099     # we by definition only have the 0th axis
#
# File c:\Users\Dell\miniconda3\lib\site-packages\pandas\core\frame.py:3867, in DataFrame._get_value(self, index, col, takeable)
#    3848 """
#    3849 Quickly retrieve single value at passed column and index.
#    3850
#    (...)
#    3864 `self.columns._index_as_unique`; Caller is responsible for checking.
#    3865 """
#    3866 if takeable:
# ...

# %%
Canada.iloc[66, 9:]
# Out:
# 1980      0
# 1981      0
# 1982      0
# 1983      0
# 1984      0
# 1985      0
# 1986      0
# 1987      0
# 1988      0
# 1989      0
# 1990      0
# 1991      0
# 1992      8
# 1993     22
# 1994     27
# 1995     67
# 1996     49
# 1997     46
# 1998     92
# 1999     46
# 2000     83
# 2001    124
# 2002    123
# 2003    127
# 2004    106
# 2005    114
# 2006    125
# 2007    132
# 2008    112
# 2009    128
# 2010    126
# 2011    139
# 2012    147
# 2013    125
# Name: 66, dtype: object

# %%
Canada.iloc[66, 9:].plot(kind='area')
# Out:
# <Axes: >

# %%
Canada.iloc[40, 9:].plot(kind='area')
# Out:
# <Axes: >

# %%
Canada
# Out:
#            Type    Coverage          OdName  AREA AreaName   REG  \
# 0    Immigrants  Foreigners     Afghanistan   935     Asia  5501
# 1    Immigrants  Foreigners         Albania   908   Europe   925
# 2    Immigrants  Foreigners         Algeria   903   Africa   912
# 3    Immigrants  Foreigners  American Samoa   909  Oceania   957
# 4    Immigrants  Foreigners         Andorra   908   Europe   925
# ..          ...         ...             ...   ...      ...   ...
# 190  Immigrants  Foreigners        Viet Nam   935     Asia   920
# 191  Immigrants  Foreigners  Western Sahara   903   Africa   912
# 192  Immigrants  Foreigners           Yemen   935     Asia   922
# 193  Immigrants  Foreigners          Zambia   903   Africa   910
# 194  Immigrants  Foreigners        Zimbabwe   903   Africa   910
#
#                 RegName  DEV             DevName  1980  1981  1982  1983  \
# 0         Southern Asia  902  Developing regions    16    39    39    47
# ...

# %%
Canada.index
# Out:
# RangeIndex(start=0, stop=195, step=1)

# %%
Canada.set_index('OdName')
# Out:
#                       Type    Coverage  AREA AreaName   REG  \
# OdName
# Afghanistan     Immigrants  Foreigners   935     Asia  5501
# Albania         Immigrants  Foreigners   908   Europe   925
# Algeria         Immigrants  Foreigners   903   Africa   912
# American Samoa  Immigrants  Foreigners   909  Oceania   957
# Andorra         Immigrants  Foreigners   908   Europe   925
# ...                    ...         ...   ...      ...   ...
# Viet Nam        Immigrants  Foreigners   935     Asia   920
# Western Sahara  Immigrants  Foreigners   903   Africa   912
# Yemen           Immigrants  Foreigners   935     Asia   922
# Zambia          Immigrants  Foreigners   903   Africa   910
# Zimbabwe        Immigrants  Foreigners   903   Africa   910
#
#                            RegName  DEV             DevName  1980  1981  1982  \
# OdName
# Afghanistan          Southern Asia  902  Developing regions    16    39    39
# ...

# %%
Canada.set_index('OdName', inplace=True) # set the 'OdName' coloumn as the index

# %%
Canada.index
# Out:
# Index(['Afghanistan', 'Albania', 'Algeria', 'American Samoa', 'Andorra',
#        'Angola', 'Antigua and Barbuda', 'Argentina', 'Armenia', 'Australia',
#        ...
#        'United States of America', 'Uruguay', 'Uzbekistan', 'Vanuatu',
#        'Venezuela (Bolivarian Republic of)', 'Viet Nam', 'Western Sahara',
#        'Yemen', 'Zambia', 'Zimbabwe'],
#       dtype='object', name='OdName', length=195)

# %%
Canada.loc['Australia']
# Out:
# Type                       Immigrants
# Coverage                   Foreigners
# AREA                              909
# AreaName                      Oceania
# REG                               927
# RegName     Australia and New Zealand
# DEV                               901
# DevName             Developed regions
# 1980                              702
# 1981                              639
# 1982                              484
# 1983                              317
# 1984                              317
# 1985                              319
# 1986                              356
# 1987                              467
# 1988                              410
# 1989                              553
# 1990                              620
# 1991                              640
# 1992                              734
# 1993                              886
# 1994                              702
# 1995                              668
# 1996                              699
# ...

# %%
years = list(range(1980, 2014))
print(years)
# Out:
# [1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013]

# %%
Canada.loc['Japan', years]
# Out:
# 1980     701
# 1981     756
# 1982     598
# 1983     309
# 1984     246
# 1985     198
# 1986     248
# 1987     422
# 1988     324
# 1989     494
# 1990     379
# 1991     506
# 1992     605
# 1993     907
# 1994     956
# 1995     826
# 1996     994
# 1997     924
# 1998     897
# 1999    1083
# 2000    1010
# 2001    1092
# 2002     806
# 2003     817
# 2004     973
# 2005    1067
# 2006    1212
# 2007    1250
# 2008    1284
# 2009    1194
# 2010    1168
# 2011    1265
# 2012    1214
# 2013     982
# Name: Japan, dtype: object

# %%
Canada.loc['Japan', years].plot(kind='area', title='Japan Immigration to Canada', figsize=(15,5))
# Out:
# <Axes: title={'center': 'Japan Immigration to Canada'}>

# %%
countries = ['China', 'Japan', 'France']
Canada.loc[countries, years]
# Out:
#         1980  1981  1982  1983  1984  1985  1986  1987  1988  1989  1990  \
# OdName
# China   5123  6682  3308  1863  1527  1816  1960  2643  2758  4323  8076
# Japan    701   756   598   309   246   198   248   422   324   494   379
# France  1729  2027  2219  1490  1169  1177  1298  1658  2038  2332  2177
#
#          1991   1992  1993   1994   1995   1996   1997   1998   1999   2000  \
# OdName
# China   14255  10846  9817  13128  14398  19415  20475  21049  30069  35529
# Japan     506    605   907    956    826    994    924    897   1083   1010
# France   2911   3487  3709   2759   3332   2623   2473   3214   3343   3765
#
#          2001   2002   2003   2004   2005   2006   2007   2008   2009   2010  \
# OdName
# China   36434  31961  36439  36619  42584  33518  27642  30037  29622  30391
# Japan    1092    806    817    973   1067   1212   1250   1284   1194   1168
# France   3806   3463   3568   4391   4429   4002   4290   4532   5051   4646
#
#          2011   2012   2013
# ...

# %%
countries = ['China', 'Japan', 'France']
Canada.loc[countries, years].plot(kind='area', title='Japan Immigration to Canada', figsize=(15,5))
# Out:
# <Axes: title={'center': 'Japan Immigration to Canada'}, xlabel='OdName'>

# %% [markdown]
# renaming columns

# %%
Canada.head()
# Out:
#            AreaName          RegName             DevName  1980  1981  1982  \
# OdName
# Lesotho      Africa  Southern Africa  Developing regions     1     1     1
# Mali         Africa   Western Africa  Developing regions     4     4     7
# Malawi       Africa   Eastern Africa  Developing regions     5     4     6
# Madagascar   Africa   Eastern Africa  Developing regions    22    10    13
# Libya        Africa  Northern Africa  Developing regions     5     7     9
#
#             1983  1984  1985  1986  1987  1988  1989  1990  1991  1992  1993  \
# OdName
# Lesotho        2     7     5     3     1     6     5     1     4     4     7
# Mali           3     3     4     3     5     4     7    13    31    90    51
# Malawi         3     2     0     4     7     1     4    10     9     4    12
# Madagascar    32    30    18    10    42    36    27    28    37    34    55
# Libya         24    10    31    23    81    43    77    47    86    89    85
#
# ...

# %%
Canada.sample()
# Out:
#                                AreaName        RegName             DevName  \
# OdName
# Guyana  Latin America and the Caribbean  South America  Developing regions
#
#         1980  1981  1982  1983  1984  1985  1986  1987  1988  1989  1990  \
# OdName
# Guyana  2334  2943  3575  2650  1932  2299  3942  6174  2977  3270  2824
#
#         1991  1992  1993  1994  1995  1996  1997  1998  1999  2000  2001  \
# OdName
# Guyana  3266  2932  3399  4181  3935  2324  1795  1238  1366  1308  1707
#
#         2002  2003  2004  2005  2006  2007  2008  2009  2010  2011  2012  \
# OdName
# Guyana  1479  1410  1341  1215  1286  1277  1137  1180   953   804   676
#
#         2013  Total
# OdName
# Guyana   656  75785

# %%
Canada.rename(mapper={
    'AreaName': 'Continent',
    'RegName':'Region',
    'DevName': 'Status'
}, axis=1,inplace=True)

# %%
Canada.head(2)
# Out:
#         Continent           Region              Status  1980  1981  1982  \
# OdName
# Lesotho    Africa  Southern Africa  Developing regions     1     1     1
# Mali       Africa   Western Africa  Developing regions     4     4     7
#
#          1983  1984  1985  1986  1987  1988  1989  1990  1991  1992  1993  \
# OdName
# Lesotho     2     7     5     3     1     6     5     1     4     4     7
# Mali        3     3     4     3     5     4     7    13    31    90    51
#
#          1994  1995  1996  1997  1998  1999  2000  2001  2002  2003  2004  \
# OdName
# Lesotho     2     3     9     2     1     4     1     0     2     2     2
# Mali       35    36    67    26    43    30    66    67    62    72    87
#
#          2005  2006  2007  2008  2009  2010  2011  2012  2013  Total
# OdName
# Lesotho     4     0     4     1     8     7     1     0     6    107
# Mali       87   114   143   154   164   170   155   191   190   2188

# %%
updated_list = ['Status', 'Continent', 'Region', 'Total']+years
print(updated_list)
# Out:
# ['Status', 'Continent', 'Region', 'Total', 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013]

# %%
Canada= Canada[updated_list] # reordring columns

# %%
Canada.head(2)
# Out:
#                      Status Continent           Region  Total  1980  1981  \
# OdName
# Lesotho  Developing regions    Africa  Southern Africa    107     1     1
# Mali     Developing regions    Africa   Western Africa   2188     4     4
#
#          1982  1983  1984  1985  1986  1987  1988  1989  1990  1991  1992  \
# OdName
# Lesotho     1     2     7     5     3     1     6     5     1     4     4
# Mali        7     3     3     4     3     5     4     7    13    31    90
#
#          1993  1994  1995  1996  1997  1998  1999  2000  2001  2002  2003  \
# OdName
# Lesotho     7     2     3     9     2     1     4     1     0     2     2
# Mali       51    35    36    67    26    43    30    66    67    62    72
#
#          2004  2005  2006  2007  2008  2009  2010  2011  2012  2013
# OdName
# Lesotho     2     4     0     4     1     8     7     1     0     6
# Mali       87    87   114   143   154   164   170   155   191   190

# %% [markdown]
# - Grouping

# %%
Canada
# Out:
#                               Status Continent                     Region  \
# OdName
# Lesotho           Developing regions    Africa            Southern Africa
# Mali              Developing regions    Africa             Western Africa
# Malawi            Developing regions    Africa             Eastern Africa
# Madagascar        Developing regions    Africa             Eastern Africa
# Libya             Developing regions    Africa            Northern Africa
# ...                              ...       ...                        ...
# Tonga             Developing regions   Oceania                  Polynesia
# Samoa             Developing regions   Oceania                  Polynesia
# Fiji              Developing regions   Oceania                  Melanesia
# New Zealand        Developed regions   Oceania  Australia and New Zealand
# Marshall Islands  Developing regions   Oceania                 Micronesia
#
# ...

# %%
Canada.groupby('Status').get_group('Developing regions')
# Out:
#                               Status Continent           Region  Total  1980  \
# OdName
# Lesotho           Developing regions    Africa  Southern Africa    107     1
# Mali              Developing regions    Africa   Western Africa   2188     4
# Malawi            Developing regions    Africa   Eastern Africa    294     5
# Madagascar        Developing regions    Africa   Eastern Africa   2194    22
# Libya             Developing regions    Africa  Northern Africa   4909     5
# ...                              ...       ...              ...    ...   ...
# Nauru             Developing regions   Oceania       Micronesia     18     1
# Tonga             Developing regions   Oceania        Polynesia    142     2
# Samoa             Developing regions   Oceania        Polynesia     78     3
# Fiji              Developing regions   Oceania        Melanesia  20609   632
# Marshall Islands  Developing regions   Oceania       Micronesia      2     0
#
# ...

# %%
Canada.groupby('Status').get_group('Developed regions')
# Out:
#                                                                Status  \
# OdName
# Japan                                               Developed regions
# Poland                                              Developed regions
# Portugal                                            Developed regions
# Croatia                                             Developed regions
# Albania                                             Developed regions
# Romania                                             Developed regions
# Russian Federation                                  Developed regions
# France                                              Developed regions
# San Marino                                          Developed regions
# Finland                                             Developed regions
# Serbia                                              Developed regions
# Estonia                                             Developed regions
# ...

# %%
Canada.groupby('Continent').get_group('Asia')
# Out:
#                                                             Status Continent  \
# OdName
# Pakistan                                        Developing regions      Asia
# Oman                                            Developing regions      Asia
# Nepal                                           Developing regions      Asia
# Maldives                                        Developing regions      Asia
# Bhutan                                          Developing regions      Asia
# Malaysia                                        Developing regions      Asia
# Brunei Darussalam                               Developing regions      Asia
# Lebanon                                         Developing regions      Asia
# Lao People's Democratic Republic                Developing regions      Asia
# Kyrgyzstan                                      Developing regions      Asia
# Kuwait                                          Developing regions      Asia
# ...

# %%
Canada.groupby('Status')[[2000,2010]].sum()
# Out:
#                       2000    2010
# Status
# Developed regions    45469   44158
# Developing regions  171243  232798

# %%
Canada.groupby('Status')[[2000,2010]].sum().plot(kind='pie',subplots=True,
                                                 labels=['D','SD'],
                                                 autopct='%1.1f%%',
                                                 figsize=(10,5),
                                                 layout=(2,1))
# Out:
# array([[<Axes: ylabel='2000'>],
#        [<Axes: ylabel='2010'>]], dtype=object)

# %%
Canada.groupby('Continent')['Total'].sum()
# Out:
# Continent
# Africa                              618948
# Asia                               3317794
# Europe                             1410947
# Latin America and the Caribbean     765148
# Northern America                    241142
# Oceania                              55174
# Name: Total, dtype: int64

# %%
# find average
Canada.groupby('Continent')['Total'].mean()
# Out:
# Continent
# Africa                              11462.000000
# Asia                                67710.081633
# Europe                              32812.720930
# Latin America and the Caribbean     23186.303030
# Northern America                   120571.000000
# Oceania                              3941.000000
# Name: Total, dtype: float64

# %%
#grouping of multiple columns
Canada.groupby('Continent')['Total'].agg(['mean','median'])
# Out:
#                                           mean    median
# Continent
# Africa                            11462.000000    2805.5
# Asia                              67710.081633    8490.0
# Europe                            32812.720930    5963.0
# Latin America and the Caribbean   23186.303030   11193.0
# Northern America                 120571.000000  120571.0
# Oceania                            3941.000000      16.5

# %%
Canada.groupby(['Continent','Region'])['Total'].sum().reset_index()
# Out:
#                           Continent                     Region    Total
# 0                            Africa             Eastern Africa   167389
# 1                            Africa              Middle Africa    48628
# 2                            Africa            Northern Africa   255451
# 3                            Africa            Southern Africa    41579
# 4                            Africa             Western Africa   105901
# 5                              Asia               Central Asia    15024
# 6                              Asia               Eastern Asia   841201
# 7                              Asia         South-Eastern Asia   687329
# 8                              Asia              Southern Asia  1398120
# 9                              Asia               Western Asia   376120
# 10                           Europe             Eastern Europe   421223
# 11                           Europe            Northern Europe   589584
# ...

# %% [markdown]
# - Pivot
# - summay in row coloumn

# %%
Canada.pivot_table(index='Status',columns='Continent', values='Total')
# Out:
# Continent            Africa          Asia       Europe  \
# Status
# Developed regions       NaN  27707.000000  32812.72093
# Developing regions  11462.0  68543.479167          NaN
#
# Continent           Latin America and the Caribbean  Northern America  \
# Status
# Developed regions                               NaN          120571.0
# Developing regions                      23186.30303               NaN
#
# Continent                Oceania
# Status
# Developed regions   17107.500000
# Developing regions   1746.583333

# %%
Canada.pivot_table(columns='Status',index='Continent', values='Total',aggfunc='mean')
# Out:
# Status                           Developed regions  Developing regions
# Continent
# Africa                                         NaN        11462.000000
# Asia                                   27707.00000        68543.479167
# Europe                                 32812.72093                 NaN
# Latin America and the Caribbean                NaN        23186.303030
# Northern America                      120571.00000                 NaN
# Oceania                                17107.50000         1746.583333

# %%
Canada.pivot_table(columns='Status',index='Continent', values='Total',aggfunc=['min','max',])
# Out:
#                                               min                     \
# Status                          Developed regions Developing regions
# Continent
# Africa                                        NaN                2.0
# Asia                                      27707.0               30.0
# Europe                                        5.0                NaN
# Latin America and the Caribbean               NaN              653.0
# Northern America                             20.0                NaN
# Oceania                                   10386.0                1.0
#
#                                               max
# Status                          Developed regions Developing regions
# Continent
# Africa                                        NaN            72745.0
# Asia                                      27707.0           691904.0
# Europe                                   551500.0                NaN
# ...

# %%
penguins = sns.load_dataset("penguins")
penguins.columns
# Out:
# Index(['species', 'island', 'bill_length_mm', 'bill_depth_mm',
#        'flipper_length_mm', 'body_mass_g', 'sex'],
#       dtype='object')

# %%
penguins.pivot_table(index='species',columns='island',values='flipper_length_mm')
# Out:
# island         Biscoe       Dream   Torgersen
# species
# Adelie     188.795455  189.732143  191.196078
# Chinstrap         NaN  195.823529         NaN
# Gentoo     217.186992         NaN         NaN

# %%
penguins_pivot=penguins.pivot_table(index='species',columns='sex',values='flipper_length_mm')
penguins_pivot
# Out:
# sex            Female        Male
# species
# Adelie     187.794521  192.410959
# Chinstrap  191.735294  199.911765
# Gentoo     212.706897  221.540984

# %%
penguins_pivot.plot(kind='bar',stacked=True,figsize=(10,5))
# Out:
# <Axes: xlabel='species'>

# %%
sns.barplot(data=penguins_pivot)
# Out:
# <Axes: xlabel='sex'>

# %%
penguins_pivot.replace(np.nan, 0, inplace=True)

# %%
penguins_pivot.astype(int)
# Out:
# sex        Female  Male
# species
# Adelie        187   192
# Chinstrap     191   199
# Gentoo        212   221

# %%
Canada.to_csv('cleaner_Canada.csv')
