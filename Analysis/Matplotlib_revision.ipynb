# %% [markdown]
# # Matplotlib Revision :--

# %%
import numpy as np
import matplotlib.pyplot as plt
import numpy as seaborn
import pandas as pd

# %% [markdown]
# - Basic Graph :--

# %%
x = ([1, 2, 3])
y = ([2, 3, 4])
plt.plot(x,y)

plt.title('Our First Graph', fontdict={'fontname':'Comic Sans MS', 'fontsize':10})
plt.xlabel('x-Axis')
plt.ylabel('y-Axis')

# if used the plt.show then not show the defining
plt.show()
