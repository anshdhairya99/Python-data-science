# %% [markdown]
# # Matplotlib Using in Python :--
# - matplotlib ( basic visulization)
# - seaborn ( advanced visulization)
# - plotly ( interactive visulization)
# - file library (pip install matplotlib seaborn plotly)

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly. express as px

# %%
penguins = sns.load_dataset("penguins")
penguins
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
penguins['bill_length_mm']
# Out:
# 0      39.1
# 1      39.5
# 2      40.3
# 3       NaN
# 4      36.7
#        ...
# 339     NaN
# 340    46.8
# 341    50.4
# 342    45.2
# 343    49.9
# Name: bill_length_mm, Length: 344, dtype: float64

# %%
penguins['bill_length_mm'].plot()
# Out:
# <Axes: >

# %%
penguins['bill_depth_mm']
# Out:
# 0      18.7
# 1      17.4
# 2      18.0
# 3       NaN
# 4      19.3
#        ...
# 339     NaN
# 340    14.3
# 341    15.7
# 342    14.8
# 343    16.1
# Name: bill_depth_mm, Length: 344, dtype: float64

# %%
penguins['bill_depth_mm'].plot()
# Out:
# <Axes: >

# %%
penguins['bill_depth_mm'].plot(linestyle='',
                               marker='x',
                               markersize=5,
                               alpha=0.7,
                               figsize=(5,5),
                               markerfacecolor='yellow',
                               markeredgecolor='black',)
# Out:
# <Axes: >

# %%
penguins['bill_depth_mm'][:50].plot(kind='bar',figsize=(15,2), color='green')
# Out:
# <Axes: >

# %%
penguins['bill_depth_mm'][:50].plot(kind='bar',figsize=(15,2), color='green')
# Out:
# <Axes: >

# %%
penguins['bill_depth_mm'][:50].plot(kind='bar',figsize=(15,4),
                                     color='blue',
                                       alpha=0.5)
# Out:
# <Axes: >

# %%
print(sns.get_dataset_names())
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'dowjones', 'exercise', 'flights', 'fmri', 'geyser', 'glue', 'healthexp', 'iris', 'mpg', 'penguins', 'planets', 'seaice', 'taxis', 'tips', 'titanic']

# %%
# it is used for machine learning
penguins.plot(kind='scatter', x='bill_length_mm', y='bill_depth_mm',s = 100, alpha=0.5)
# Out:
# <Axes: xlabel='bill_length_mm', ylabel='bill_depth_mm'>

# %%
penguins.plot(kind='scatter', x='bill_length_mm', y='flipper_length_mm',s = 100, alpha=0.5)
# Out:
# <Axes: xlabel='bill_length_mm', ylabel='flipper_length_mm'>

# %% [markdown]
# - multiple graph
#
# - Subplots

# %%
fig, axs = plt.subplots(2, 2, figsize=(15, 4), constrained_layout= True )

# %%
fig, axs = plt.subplots(1, 2, figsize=(15, 4), constrained_layout= True )
penguins.plot(kind='scatter', x='bill_length_mm', y='flipper_length_mm',s = 100, alpha=0.5, ax=axs[0], title='penguin bill data')
penguins.plot(kind='scatter', x='bill_length_mm', y='flipper_length_mm',s = 100, alpha=0.5,ax=axs[1], title='penguin bill data')
penguins.plot(kind='scatter', x='bill_length_mm', y='flipper_length_mm',s = 100, alpha=0.5,ax=axs[1], title='penguin flipper')


plt.show()

# %%
print(axs)
# Out:
# [<Axes: title={'center': 'penguin bill data'}, xlabel='bill_length_mm', ylabel='flipper_length_mm'>
#  <Axes: title={'center': 'penguin flipper'}, xlabel='bill_length_mm', ylabel='flipper_length_mm'>]

# %%
penguins['species'].value_counts().plot(kind='pie',
                                        autopct='%1.1f%%', # add in percentage
                                        figsize=(3,3),
                                        title='Species',
                                        ylabel='',
                                        pctdistance=.7,
                                        wedgeprops = dict(
                                            width=0.5,
                                        ))
# Out:
# <Axes: title={'center': 'Species'}>
